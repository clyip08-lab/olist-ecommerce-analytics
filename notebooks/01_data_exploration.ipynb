# %%
import pandas as pd
import os

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
DATA_PATH = r"C:\Users\yipch\OneDrive\Desktop\olist_analytics\data"

customers   = pd.read_csv(os.path.join(DATA_PATH, "olist_customers_dataset.csv"))
orders      = pd.read_csv(os.path.join(DATA_PATH, "olist_orders_dataset.csv"))
order_items = pd.read_csv(os.path.join(DATA_PATH, "olist_order_items_dataset.csv"))
payments    = pd.read_csv(os.path.join(DATA_PATH, "olist_order_payments_dataset.csv"))
reviews     = pd.read_csv(os.path.join(DATA_PATH, "olist_order_reviews_dataset.csv"))
products    = pd.read_csv(os.path.join(DATA_PATH, "olist_products_dataset.csv"))
sellers     = pd.read_csv(os.path.join(DATA_PATH, "olist_sellers_dataset.csv"))
geolocation = pd.read_csv(os.path.join(DATA_PATH, "olist_geolocation_dataset.csv"))
category    = pd.read_csv(os.path.join(DATA_PATH, "product_category_name_translation.csv"))

print("✅ All files loaded successfully!")
# Out:
# ✅ All files loaded successfully!

# %%
datasets = {
    "customers":   customers,
    "orders":      orders,
    "order_items": order_items,
    "payments":    payments,
    "reviews":     reviews,
    "products":    products,
    "sellers":     sellers,
    "geolocation": geolocation,
    "category":    category
}

print(f"{'Dataset':<20} {'Rows':>10} {'Columns':>10}")
print("-" * 42)
for name, df in datasets.items():
    print(f"{name:<20} {df.shape[0]:>10,} {df.shape[1]:>10}")
# Out:
# Dataset                    Rows    Columns
# ------------------------------------------
# customers                99,441          5
# orders                   99,441          8
# order_items             112,650          7
# payments                103,886          5
# reviews                  99,224          7
# products                 32,951          9
# sellers                   3,095          4
# geolocation           1,000,163          5
# category                     71          2

# %%
for name, df in datasets.items():
    print(f"\n{'='*50}")
    print(f"📄 {name.upper()}")
    print(f"{'='*50}")
    print(df.head(3))
# Out:
# ...
# 📄 CUSTOMERS
# ...
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
#
# ...
# 📄 ORDERS
# ...
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
for name, df in datasets.items():
    print(f"\n{'='*50}")
    print(f"🔍 {name.upper()} — Nulls & Dtypes")
    print(f"{'='*50}")
    info = pd.DataFrame({
        'dtype':    df.dtypes,
        'nulls':    df.isnull().sum(),
        'null_%':   (df.isnull().sum() / len(df) * 100).round(2)
    })
    print(info[info['nulls'] > 0] if info['nulls'].sum() > 0 else "No nulls ✅")
# Out:
# ...
# 🔍 CUSTOMERS — Nulls & Dtypes
# ...
# No nulls ✅
#
# ...
# 🔍 ORDERS — Nulls & Dtypes
# ...
#                               dtype  nulls  null_%
# order_approved_at               str    160    0.16
# order_delivered_carrier_date    str   1783    1.79
# order_delivered_customer_date   str   2965    2.98
#
# ...
# 🔍 ORDER_ITEMS — Nulls & Dtypes
# ...
# No nulls ✅
#
# ...
# 🔍 PAYMENTS — Nulls & Dtypes
# ...
# No nulls ✅
#
# ...
# 🔍 REVIEWS — Nulls & Dtypes
# ...
#                        dtype  nulls  null_%
# review_comment_title     str  87656   88.34
# review_comment_message   str  58247   58.70
#
# ...
# 🔍 PRODUCTS — Nulls & Dtypes
# ...
#                               dtype  nulls  null_%
# product_category_name           str    610    1.85
# product_name_lenght         float64    610    1.85
# product_description_lenght  float64    610    1.85
# product_photos_qty          float64    610    1.85
# product_weight_g            float64      2    0.01
# product_length_cm           float64      2    0.01
# ...

# %%
print("🔗 KEY RELATIONSHIPS")
print("-" * 50)
print(f"orders → customers    via: customer_id")
print(f"orders → order_items  via: order_id")
print(f"orders → payments     via: order_id")
print(f"orders → reviews      via: order_id")
print(f"order_items → products via: product_id")
print(f"order_items → sellers  via: seller_id")
print(f"products → category   via: product_category_name")
print()
print(f"Total unique orders:    {orders['order_id'].nunique():,}")
print(f"Total unique customers: {customers['customer_id'].nunique():,}")
print(f"Total unique products:  {products['product_id'].nunique():,}")
print(f"Total unique sellers:   {sellers['seller_id'].nunique():,}")
# Out:
# 🔗 KEY RELATIONSHIPS
# --------------------------------------------------
# orders → customers    via: customer_id
# orders → order_items  via: order_id
# orders → payments     via: order_id
# orders → reviews      via: order_id
# order_items → products via: product_id
# order_items → sellers  via: seller_id
# products → category   via: product_category_name
#
# Total unique orders:    99,441
# Total unique customers: 99,441
# Total unique products:  32,951
# Total unique sellers:   3,095
